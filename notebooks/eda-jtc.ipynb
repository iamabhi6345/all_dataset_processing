# %%
cd /app
# Out:
# /app
# /home/abhi/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd

# %%
train_df = pd.read_csv("./data/raw/jigsaw-toxic-comments/train.csv")
test_df = pd.read_csv("./data/raw/jigsaw-toxic-comments/test.csv")
test_labels_df = pd.read_csv("./data/raw/jigsaw-toxic-comments/test_labels.csv")

# %%
print(f"{train_df.shape=}")
print(f"{test_df.shape=}")
print(f"{test_labels_df.shape=}")
# Out:
# train_df.shape=(159571, 8)
# test_df.shape=(153164, 2)
# test_labels_df.shape=(153164, 7)

# %%
len(train_df) * 0.06
# Out:
# 9574.26

# %%
train_df.sample(n=50)
# Out:
#                       id                                       comment_text  \
# 104023  2c88e787b3933f56  Never mind, but if you have time or are involv...
# 99109   1231a2c73f291c34              Nope \n\nCertainly not! 86.176.166.76
# 44389   768fc3a606bc6c75  Good intentions \n\nHi Yan,\n\nI fail to see t...
# 42702   71f44d069d63df58                 See Amplitude modulation )  (talk)
# 22742   3c0f4b5248c92bbf  I apologize for the Tom Cruise thing, there wa...
# 43072   72e790b1116f6a8b  "\nMorning, Gareth! Thank you for that - altho...
# 70400   bc5a1e21fdeac88a  I can also email your message to the class.\n\...
# 7117    12faa25b38e01dcf  "\n\n A kitten for you! \n\nThank you for your...
# 84831   e2fda4d7e3cf4dea  "\nSame as Apennine Peninsula vs Italian Repub...
# 153753  a20c6c4decc8bef0  ":::a-ha, so argue rectitude of original edit ...
# 77031   ce4f7bd4e336140f  dude you guys must be on crack! instead of blo...
# 141508  f50f36d81720f47c  Well, you blocked the page for 5 days until he...
# 157686  e2159fb55e8f31b1  Sorry dude, but what a load of malarkie! 04:48...
# 20174   354a033b60daaf3c                       "\nI am what I am.  (talk) "
# 69503   b9e68a927c2d5da2  Yes I am a terrible person for not appreciatin...
# 126107  a26817f893a354ee  Hopefully if we can get T25 its own article th...
# 67730   b5372521760450c7  Thank you for experimenting with  Wikipedia. Y...
# 137508  dfccb72437cd4a80  james bond (character) page \n\nhey guys, mayb...
# 102003  21e52efe416dc18b                "\n\n Request to be Unblocked \n\n"
# 67564   b4cc75b052105efe  "\nI think I forgot\nTo thank you for helping ...
# 115249  6845f0b595ee8d26  these two towns are one in the same.  The offi...
# 14892   27593a123ad68116  "\nMerged with Pentateuch\nI merged this artic...
# 121150  88280c31883d978c  "\n\n Please do not vandalize pages, as you di...
# 5233    0debddf1cb002d66  "\nHmmm... innuedo?!? How's about this one... ...
# 33164   584a0e81b689211a  This is such a joke and proves Wikipedia is a ...
# 44342   766c5ac4f219e867                            Taiwu of Northern Wei]]
# 12723   21c07b73400dcdb4  "\n\n RfC \n\nThere is a Request for Comment n...
# 73471   c49414f3c192f0f1  Just wanted to flick in with that this user ha...
# 20051   34fc48eadbc1dff6  "\nA ""no consensus"" means that participants ...
# 125685  a0602fcb4688d929                  someone who works for the station
# 49970   859a39f510dfe143  Blood Bros., DoDonPachi, Final Fight, Garou: M...
# 14864   274b0dc91ead8f85  This message is regarding the page Stem cell. ...
# 20853   3709b76795608305  "\n\n des contradictions de Wikipédia qui enco...
# 6760    1205df6b7d9db04c  "\n\n Recent addition to True Finns \n\nYour e...
# 156726  d2b6ebce0790c683  HEY YOU MOTHER FUCKER I PUT HARD WORK INTO MY ...
# 138224  e3aef688850d3e94                         Hello! I am a female dog..
# 128419  aecd4ab23b851047             As always. You couldn't be more wrong.
# 156022  c7afe81971edaeba  If you look at the anfal page, you will see th...
# 156731  d2c8daa9b7253c77  I would like to make amends for some of those ...
# 132958  c74ce73d534ea15a  October 2008 \n Please stop your disruptive ed...
# 44427   76a6ca0522a90580  Jennifer Morrison \n\nPlease do not continue t...
# 4889    0cf317a5ebb8e778               "\nGot it. Thanks!  (Talk • Phils) "
# 113327  5e098d8ddc9a1377  ")\n\nNo, it's not a murder until they say it ...
# 150020  65767f7e5d35b881               You little bitch ass Wikipedia nerd.
# 47412   7ea348e90bf35c47  "\n\n Request opinion of Muslim editor \n\nHel...
# 98285   0dc343ca35ff3234  "\nIf you seriously think that ""described by ...
# 64181   abbf0a2aef56d0c7  Welcome to Wikipedia and thank you for your co...
# 59242   9eb99b6432ec557c  tourettes \n\nYou know what sandy georgia you ...
# 73498   c4a8f15880eca416  "\nOne problem. The land belongs to Syria and ...
# 8191    15c63bdde040e6b3  "\n\n, you are correct about the ""авиа́ции"" ...
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate
# 104023      0             0        0       0       0              0
# 99109       0             0        0       0       0              0
# 44389       0             0        0       0       0              0
# 42702       0             0        0       0       0              0
# 22742       0             0        0       0       0              0
# 43072       0             0        0       0       0              0
# 70400       0             0        0       0       0              0
# 7117        0             0        0       0       0              0
# 84831       0             0        0       0       0              0
# 153753      0             0        0       0       0              0
# 77031       0             0        0       0       0              0
# 141508      0             0        0       0       0              0
# 157686      0             0        0       0       0              0
# 20174       0             0        0       0       0              0
# 69503       0             0        0       0       0              0
# 126107      0             0        0       0       0              0
# 67730       0             0        0       0       0              0
# 137508      0             0        0       0       0              0
# 102003      0             0        0       0       0              0
# 67564       0             0        0       0       0              0
# 115249      0             0        0       0       0              0
# 14892       0             0        0       0       0              0
# 121150      0             0        0       0       0              0
# 5233        0             0        0       0       0              0
# 33164       1             0        0       0       0              0
# 44342       0             0        0       0       0              0
# 12723       0             0        0       0       0              0
# 73471       0             0        0       0       0              0
# 20051       0             0        0       0       0              0
# 125685      0             0        0       0       0              0
# 49970       0             0        0       0       0              0
# 14864       0             0        0       0       0              0
# 20853       0             0        0       0       0              0
# 6760        0             0        0       0       0              0
# 156726      1             1        1       0       1              0
# 138224      0             0        0       0       0              0
# 128419      0             0        0       0       0              0
# 156022      0             0        0       0       0              0
# 156731      0             0        0       0       0              0
# 132958      0             0        0       0       0              0
# 44427       0             0        0       0       0              0
# 4889        0             0        0       0       0              0
# 113327      0             0        0       0       0              0
# 150020      1             0        1       0       1              0
# 47412       0             0        0       0       0              0
# 98285       0             0        0       0       0              0
# 64181       0             0        0       0       0              0
# 59242       0             0        0       0       0              0
# 73498       0             0        0       0       0              0
# 8191        0             0        0       0       0              0

# %%
train_df["identity_hate"].unique()
# Out:
# array([0, 1])

# %%
test_df.head(50)
# Out:
#                   id                                       comment_text
# 0   00001cee341fdb12  Yo bitch Ja Rule is more succesful then you'll...
# 1   0000247867823ef7  == From RfC == \n\n The title is fine as it is...
# 2   00013b17ad220c46  " \n\n == Sources == \n\n * Zawe Ashton on Lap...
# 3   00017563c3f7919a  :If you have a look back at the source, the in...
# 4   00017695ad8997eb          I don't anonymously edit articles at all.
# 5   0001ea8717f6de06  Thank you for understanding. I think very high...
# 6   00024115d4cbde0f  Please do not add nonsense to Wikipedia. Such ...
# 7   000247e83dcc1211                   :Dear god this site is horrible.
# 8   00025358d4737918  " \n Only a fool can believe in such numbers. ...
# 9   00026d1092fe71cc  == Double Redirects == \n\n When fixing double...
# 10  0002eadc3b301559  I think its crap that the link to roggenbier i...
# 11  0002f87b16116a7f  "::: Somebody will invariably try to add Relig...
# 12  0003806b11932181  , 25 February 2010 (UTC) \n\n :::Looking it ov...
# 13  0003e1cccfd5a40a  " \n\n It says it right there that it IS a typ...
# 14  00059ace3e3e9a53  " \n\n == Before adding a new product to the l...
# 15  000634272d0d44eb  ==Current Position== \n Anyone have confirmati...
# 16  000663aff0fffc80                           this other one from 1897
# 17  000689dd34e20979  == Reason for banning throwing == \n\n This ar...
# 18  000834769115370c  :: Wallamoose was changing the cited material ...
# 19  000844b52dee5f3f             |blocked]] from editing Wikipedia.   |
# 20  00084da5d4ead7aa  ==Indefinitely blocked== \n I have indefinitel...
# 21  00091c35fa9d0465  == Arabs are committing genocide in Iraq, but ...
# 22  000968ce11f5ee34  Please stop. If you continue to vandalize Wiki...
# 23  0009734200a85047  == Energy  == \n\n I have edited the introduct...
# 24  00097b6214686db5  :yeah, thanks for reviving the tradition of pi...
# 25  0009aef4bd9e1697  MLM Software,NBFC software,Non Banking Financi...
# 26  000a02d807ae0254  @RedSlash, cut it short. If you have sources s...
# 27  000a6c6d4e89b9bc  ==================== \n Deception is the way o...
# 28  000bafe2080bba82  . \n\n           Jews are not a race because y...
# 29  000bf0a9894b2807  :::If Ollie or others think that one list of t...
# 30  000c50dceb1eed2b  " \n *Support Per Jimbo and WP:google ""Climat...
# 31  000c9b92318552d1               Professors to the Manhatten Project.
# 32  000ce41d86f2b886  :::::I have added more wikilinks to my section...
# 33  000cf60dbaed8c02  " \n\n :Not sure whether this is notable enoug...
# 34  000d4f120d5a7303                       일이삼사오육칠팔구하고십이요 에헤헤 으헤 으헤 으허허
# 35  000d60becb7d1a67  I've deleted the page , as we have no evidence...
# 36  000fc381d4895598  == Nation Radio - request for comment == \n\n ...
# 37  000ff37cf57ab537                          """ (per your user page)"
# 38  001068b809feee6b  " \n\n ==balance== \n This page has one senten...
# 39  0011c58fcfd6bf91  " \n\n *@EdJohnston. Your question was about f...
# 40  0011cefc680993ba                      REDIRECT Talk:Mi Vida Eres Tú
# 41  0011ef6aa33d42e6  " \n I'm not convinced that he was blind. Wher...
# 42  0012706ac77a7b37  == Thanks for the Barnstar! == \n\n Thank you ...
# 43  0012bb72f20ae971  " \n\n == Ref: SS Ponzi Scheme == \n\n Hi Padi...
# 44  0012bbcbd6958302  " \n\n Look, Gerry Spence has NOT ""never lost...
# 45  00137446b1aec28c  == September 20th Truce == \n\n According to s...
# 46  0013a435effa29bd  I'd never think I'd need to say it, but Wikipe...
# 47  0013be435187e84f  But this is not the article about government p...
# 48  0013fed3aeae76b7  DJ Robinson is gay as hell! he sucks his dick ...
# 49  001411adf8f1dd82  == Dracula's Grandmother == \n\n  \n Dracula's...

# %%
test_labels_df.head(10)
# Out:
#                  id  toxic  severe_toxic  obscene  threat  insult  \
# 0  00001cee341fdb12     -1            -1       -1      -1      -1
# 1  0000247867823ef7     -1            -1       -1      -1      -1
# 2  00013b17ad220c46     -1            -1       -1      -1      -1
# 3  00017563c3f7919a     -1            -1       -1      -1      -1
# 4  00017695ad8997eb     -1            -1       -1      -1      -1
# 5  0001ea8717f6de06      0             0        0       0       0
# 6  00024115d4cbde0f     -1            -1       -1      -1      -1
# 7  000247e83dcc1211      0             0        0       0       0
# 8  00025358d4737918     -1            -1       -1      -1      -1
# 9  00026d1092fe71cc     -1            -1       -1      -1      -1
#
#    identity_hate
# 0             -1
# 1             -1
# 2             -1
# 3             -1
# 4             -1
# 5              0
# 6             -1
# 7              0
# 8             -1
# 9             -1

# %%
test_labels_df["toxic"].unique()
# Out:
# array([-1,  0,  1])

# %%
test_labels_df[test_labels_df["toxic"] != -1].shape
# Out:
# (63978, 7)

# %%
test_labels_df[
    (test_labels_df["toxic"] != -1) &
    (test_labels_df["severe_toxic"] != -1) &
    (test_labels_df["obscene"] != -1) &
    (test_labels_df["threat"] != -1) &
    (test_labels_df["insult"] != -1) &
    (test_labels_df["identity_hate"] != -1)
].shape
# Out:
# (63978, 7)
